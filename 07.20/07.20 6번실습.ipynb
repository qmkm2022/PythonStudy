# %% [markdown]
# 1. 대학평가

# %% [markdown]
# 로지스틱 회귀분석   -   logistic, sigmoid 0.0~1.0
#
# 의사결정나무        -   규칙기반
#
# 랜덤포레스트
#
# 사례기반추론
#
# SVM                 -   support vector machine
#
# 인공신경망

# %%
# 대학평가(kaggle에서 수집한 데이터를 가공하여 실습)

import pandas as pd

df = pd.read_csv("c:/workspace/data/school/data.csv")

df.head()
# Out:
#    teaching  international  research  citations  income  num_students  \
# 0      12.4           95.6      10.6       13.3    33.3          5226
# 1      29.9           90.1      20.1       65.3    33.9          2473
# 2      24.7           82.6      18.9       43.5    28.4          2473
# 3      61.3           98.6      67.5       94.6    65.4          9666
# 4      62.4           98.8      57.0       95.0    49.8          9666
#
#    student_staff_ratio  international_students  total_score  Label
# 0                 14.1                    0.82         59.8      0
# 1                 15.6                    0.63         59.8      0
# 2                 15.6                    0.63         59.8      0
# 3                 10.5                    0.54         76.1      1
# 4                 10.5                    0.54         73.0      1

# %%
train_cols = df.columns[0:8]

print(train_cols)

X = df[train_cols] # 독립변수

y = df["Label"] # 종속변수
# Out:
# Index(['teaching', 'international', 'research', 'citations', 'income',
#        'num_students', 'student_staff_ratio', 'international_students'],
#       dtype='object')

# %%
df["Label"].value_counts()
# Out:
# Label
# 0    2158
# 1     445
# Name: count, dtype: int64

# %%
import pandas as pd

import matplotlib.pyplot as plt

from matplotlib import font_manager, rc

# 한글 처리를 위해 폰트 설정

font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()

rc('font', family=font_name)

import seaborn as sns

colors = ["yellow", "red"]

sns.countplot(x='Label', data=df, palette=colors)

plt.title('분류\n (0: bad, 1: good)', fontsize=14)

# 불균형 데이터셋
# Out:
# Text(0.5, 1.0, '분류\n (0: bad, 1: good)')

# %%
# 언더샘플링

from imblearn.under_sampling import RandomUnderSampler

X_sample, y_sample = RandomUnderSampler(random_state=0).fit_resample(X, y)

X_samp = pd.DataFrame(data=X_sample,columns=train_cols )

y_samp = pd.DataFrame(data=y_sample,columns=['Label'])

df_samp=pd.concat([X_samp,y_samp],axis=1)

df_samp["Label"].value_counts()
# Out:
# Label
# 0    445
# 1    445
# Name: count, dtype: int64

# %%
X=df_samp[train_cols]

y=df_samp["Label"]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(

    X, y, test_size=0.2, stratify=y,random_state=10)

# %%
# 로지스틱 회귀분석

from sklearn.linear_model import LogisticRegression

logit = LogisticRegression(random_state=10,max_iter=1000)

logit.fit(X_train, y_train)

print("학습용:",logit.score(X_train, y_train))

print("검증용:",logit.score(X_test, y_test))
# Out:
# 학습용: 0.8890449438202247
# 검증용: 0.8539325842696629

# %%
from sklearn.preprocessing import StandardScaler

scaler= StandardScaler()

scaler.fit(X_train)

X_train_scaled = pd.DataFrame(scaler.transform(X_train))

X_test_scaled = pd.DataFrame(scaler.transform(X_test))

# %%
#다양한 알고리즘별 정확도를 저장할 리스트

result_tr=[]

result_te=[]

# %%
logit = LogisticRegression(random_state=10)

logit.fit(X_train_scaled, y_train)

score_tr=logit.score(X_train_scaled, y_train)

score_te=logit.score(X_test_scaled, y_test)

print("학습용:",score_tr)

print("검증용:",score_te)

result_tr.append(score_tr)

result_te.append(score_te)
# Out:
# 학습용: 0.9887640449438202
# 검증용: 0.9943820224719101

# %%
# 의사결정나무

from sklearn.tree import DecisionTreeClassifier

tree = DecisionTreeClassifier(random_state=10)

tree.fit(X_train_scaled, y_train)

print("학습용:",tree.score(X_train_scaled, y_train))

print("검증용:",tree.score(X_test_scaled, y_test))
# Out:
# 학습용: 1.0
# 검증용: 0.9719101123595506

# %%
# max_depth 가지치기

tree = DecisionTreeClassifier(max_depth=4, random_state=10)

tree.fit(X_train_scaled, y_train)

score_tr=tree.score(X_train_scaled, y_train)

score_te=tree.score(X_test_scaled, y_test)

print("학습용:",score_tr)

print("검증용:",score_te)
# Out:
# 학습용: 0.9789325842696629
# 검증용: 0.9775280898876404

# %%
result_tr.append(score_tr)

result_te.append(score_te)

# %%
from sklearn.tree import export_graphviz

import pydotplus

from IPython.display import Image

dot_data = export_graphviz(tree, out_file=None, feature_names=train_cols, class_names=["0","1"], filled=True, rounded=True, special_characters=True)

graph = pydotplus.graph_from_dot_data(dot_data)

Image(graph.create_png())

# %% [markdown]
# entropy     혼잡도
# 0~1

# %%
#트리를 만드는 결정에 각 특성이 얼마나 중요한지를 평가하는 특성 중요도 적용

#0~1 사이의 값(0 전혀 사용되지 않음 ~ 1 완벽하게 타겟 클래스 예측)

import numpy as np

def plot_tree(model):

    n_features = X.shape[1]
#               변수의 개수

    plt.rcParams["figure.figsize"]=(16,9)
#                                   그래프 크기    

    plt.barh(range(n_features), model.feature_importances_, align='center')

    plt.yticks(np.arange(n_features), train_cols)

    plt.xlabel("특성 중요도")

    plt.ylabel("특성")

    plt.ylim(-1, n_features)

plot_tree(tree)

#특성 중요도 :

# %%
#랜덤포레스트

from sklearn.ensemble import RandomForestClassifier

#100개의 트리로 구성된 랜덤 포레스트

forest = RandomForestClassifier(n_estimators=100, random_state=10)

forest.fit(X_train_scaled, y_train)

score_tr=forest.score(X_train_scaled, y_train)

score_te=forest.score(X_test_scaled, y_test)

print("학습용:",score_tr)

print("검증용:",score_te)
# Out:
# 학습용: 1.0
# 검증용: 0.9943820224719101

# %%
result_tr.append(score_tr)

result_te.append(score_te)

# %%
#랜덤 포레스트에서 제공하는 각 트리의 특성 중요도

#랜덤 포레스트는 좀 더 폭넓은 시각으로 데이터를 관찰할 수 있다

plot_tree(forest)

#특성 중요도 :

# %% [markdown]
# 사례기반 추론(KNN)
#
# k 이웃의 수 2
#
#      x
#
#         *
#
#            x
#
#     o
#
#
# 유클리드 거리   -   직선
#
#
# 맨해튼 거리

# %%
#knn

from sklearn.neighbors import KNeighborsClassifier

import numpy as np

train_rate = []

test_rate = []
# 새로운 데이터 포인트에 가장 가까운 k개의 이웃을 찾는다.

# k의 값에 따라 결과가 달라지므로 어떤 값이 최적인지 찾아내는 것이 필요함

# 1 에서 10 까지 n_neighbors 를 적용

neighbors = range(1, 11)

for n in neighbors:

    # 모델 생성

    knn = KNeighborsClassifier(n_neighbors=n)

    knn.fit(X_train_scaled, y_train)

    # 학습용 데이터셋의 정확도

    train_rate.append(knn.score(X_train_scaled, y_train))

    # 검증용 데이터셋의 정확도

    test_rate.append(knn.score(X_test_scaled, y_test))

test_arr=np.array(test_rate) #검증용 데이터셋의 정확도

max_rate=np.max(test_arr) #가장 좋은 정확도

idx=np.where(test_arr == max_rate)[0][0] #가장 성능이 좋은 인덱스

print("최적의 k:",neighbors[idx])

print("최고 정확도:",test_rate[idx])
# Out:
# 최적의 k: 5
# 최고 정확도: 0.9887640449438202

# %%
plt.rcParams["font.size"]=15

plt.plot(neighbors, train_rate, label="학습용 데이터셋")

plt.plot(neighbors, test_rate, label="검증용 데이터셋")

plt.ylabel("정확도")

plt.xlabel("이웃의 수")

plt.legend()

#학습용 데이터셋의 경우 이웃이 1개일 때 100% 예측

#이웃의 수가 늘어나면 학습용 데이터셋의 경우 모델이 단순해지고 정확도는 줄어든다.

# %%
knn = KNeighborsClassifier(n_neighbors=3)

knn.fit(X_train_scaled, y_train)

score_tr=knn.score(X_train_scaled, y_train)

score_te=knn.score(X_test_scaled, y_test)

print("학습용:",score_tr)

print("검증용:",score_te)
# Out:
# 학습용: 0.9803370786516854
# 검증용: 0.9719101123595506

# %%
result_tr.append(score_tr)

result_te.append(score_te)

# %%
# 인공신경망

from sklearn.neural_network import MLPClassifier

mlp = MLPClassifier(random_state=10)

mlp.fit(X_train_scaled, y_train)

print("학습용:",mlp.score(X_train_scaled, y_train))

print("검증용:",mlp.score(X_test_scaled, y_test))
# Out:
# 학습용: 0.9943820224719101
# 검증용: 0.9943820224719101
# c:\Users\tjoeun\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
score_tr=mlp.score(X_train_scaled, y_train)

score_te=mlp.score(X_test_scaled, y_test)

print("학습용:",score_tr)

print("검증용:",score_te)
# Out:
# 학습용: 0.9943820224719101
# 검증용: 0.9943820224719101

# %%
result_tr.append(score_tr)

result_te.append(score_te)

# %%
# SVM

from sklearn.svm import SVC

svm = SVC(random_state=10)

svm.fit(X_train_scaled, y_train)

print("학습용:",svm.score(X_train_scaled, y_train))

print("검증용:",svm.score(X_test_scaled, y_test))
# Out:
# 학습용: 0.9873595505617978
# 검증용: 0.9887640449438202

# %%
#최적의 C value와 gamma value를 찾는 과정

import numpy as np

train_rate = []

test_rate = []

c_values = [0.001, 0.01, 0.1, 1, 10, 100, 1000]

g_values = [0.0001, 0.001, 0.01, 0.1]

for n in c_values:

    for g in g_values:

        # 모델 생성

        svm = SVC(C=n,gamma=g,random_state=10)

        svm.fit(X_train_scaled, y_train)

        # 학습용 데이터셋의 정확도

        train_rate.append([n,g,svm.score(X_train_scaled, y_train)])

        # 검증용 데이터셋의 정확도

        test_rate.append([n,g,svm.score(X_test_scaled, y_test)])

train_arr=np.array(train_rate) #검증용 데이터셋의 정확도

test_arr=np.array(test_rate) #검증용 데이터셋의 정확도

max_rate=np.max(test_arr[:,2]) #가장 좋은 정확도

idx=np.argmax(test_arr[:,2]) #가장 성능이 좋은 인덱스

print("최적의 c:",test_rate[idx][0])

print("최적의 gamma:",test_rate[idx][1])

print("최고 정확도:",test_rate[idx][2])
# Out:
# 최적의 c: 100
# 최적의 gamma: 0.01
# 최고 정확도: 1.0

# %%
plt.rcParams["font.size"]=15

plt.plot(range(len(train_rate)), train_arr[:,2], label="학습용 데이터셋")

plt.plot(range(len(test_rate)), test_arr[:,2], label="검증용 데이터셋")

plt.ylabel("정확도")

plt.legend()

# %%
from sklearn.svm import SVC

svm = SVC(C=100,gamma=0.01,random_state=10)
# C     -   오차에 대한 패널티
# gamma -   개별 샘플의 영향력   

svm.fit(X_train_scaled, y_train)

score_tr=svm.score(X_train_scaled, y_train)

score_te=svm.score(X_test_scaled, y_test)

print("학습용:",score_tr)

print("검증용:",score_te)
# Out:
# 학습용: 0.9929775280898876
# 검증용: 1.0

# %%
result_tr.append(score_tr)

result_te.append(score_te)

# %%
from keras.models import Sequential

from keras.layers import Dense

from keras.optimizers import SGD

model = Sequential()

model.add(Dense(64,input_shape=(X.shape[1],),activation='relu'))

model.add(Dense(64,activation='relu'))

model.add(Dense(1,activation='sigmoid'))

sgd = SGD(learning_rate=0.01)  

model.compile(loss='binary_crossentropy', optimizer=sgd, metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 64)                576
#
#  dense_4 (Dense)             (None, 64)                4160
#
#  dense_5 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 4,801
# Trainable params: 4,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils import plot_model  

plot_model(model,show_shapes=True)

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, CSVLogger

es = EarlyStopping(monitor='val_loss', patience=5)

# 학습 과정에서 만들어진 최적의 파라미터 조합으로 모형을 저장

mc = ModelCheckpoint("school_best.h5", save_best_only=True)

# 학습이 잘 안될 때 학습률을 동적으로 조절하는 옵션

rlr = ReduceLROnPlateau(factor=0.1, patience=5) 

# 기존 학습률*factor (배수)

# 학습 과정의 주요 history를 csv로 저장

csvlogger = CSVLogger("mylog.csv")  

hist = model.fit(X_train_scaled, y_train, validation_split=0.2, epochs=500, callbacks=[es, mc, rlr, csvlogger])
# Out:
# Epoch 1/500
# 18/18 [==============================] - 1s 15ms/step - loss: 0.7558 - accuracy: 0.3761 - val_loss: 0.7202 - val_accuracy: 0.4126 - lr: 0.0100
# Epoch 2/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.6785 - accuracy: 0.5395 - val_loss: 0.6486 - val_accuracy: 0.6783 - lr: 0.0100
# Epoch 3/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.6180 - accuracy: 0.7961 - val_loss: 0.5895 - val_accuracy: 0.8462 - lr: 0.0100
# Epoch 4/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.5664 - accuracy: 0.8822 - val_loss: 0.5378 - val_accuracy: 0.9161 - lr: 0.0100
# Epoch 5/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.5206 - accuracy: 0.9033 - val_loss: 0.4913 - val_accuracy: 0.9231 - lr: 0.0100
# Epoch 6/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4790 - accuracy: 0.9174 - val_loss: 0.4491 - val_accuracy: 0.9231 - lr: 0.0100
# Epoch 7/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4413 - accuracy: 0.9297 - val_loss: 0.4111 - val_accuracy: 0.9371 - lr: 0.0100
# Epoch 8/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.4072 - accuracy: 0.9367 - val_loss: 0.3769 - val_accuracy: 0.9510 - lr: 0.0100
# Epoch 9/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.3762 - accuracy: 0.9420 - val_loss: 0.3461 - val_accuracy: 0.9580 - lr: 0.0100
# Epoch 10/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.3484 - accuracy: 0.9473 - val_loss: 0.3186 - val_accuracy: 0.9580 - lr: 0.0100
# Epoch 11/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.3237 - accuracy: 0.9490 - val_loss: 0.2942 - val_accuracy: 0.9580 - lr: 0.0100
# Epoch 12/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.3016 - accuracy: 0.9525 - val_loss: 0.2726 - val_accuracy: 0.9790 - lr: 0.0100
# Epoch 13/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.2820 - accuracy: 0.9543 - val_loss: 0.2537 - val_accuracy: 0.9790 - lr: 0.0100
# Epoch 14/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.2645 - accuracy: 0.9543 - val_loss: 0.2368 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 15/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.2490 - accuracy: 0.9508 - val_loss: 0.2219 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 16/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.2352 - accuracy: 0.9508 - val_loss: 0.2087 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 17/500
# 18/18 [==============================] - 0s 9ms/step - loss: 0.2228 - accuracy: 0.9525 - val_loss: 0.1968 - val_accuracy: 0.9860 - lr: 0.0100
# Epoch 18/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.2117 - accuracy: 0.9596 - val_loss: 0.1863 - val_accuracy: 0.9860 - lr: 0.0100
# Epoch 19/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.2017 - accuracy: 0.9596 - val_loss: 0.1770 - val_accuracy: 0.9860 - lr: 0.0100
# Epoch 20/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.1927 - accuracy: 0.9596 - val_loss: 0.1685 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 21/500
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1846 - accuracy: 0.9613 - val_loss: 0.1609 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 22/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.1771 - accuracy: 0.9596 - val_loss: 0.1540 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 23/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.1702 - accuracy: 0.9596 - val_loss: 0.1477 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 24/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.1639 - accuracy: 0.9613 - val_loss: 0.1421 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 25/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.1582 - accuracy: 0.9613 - val_loss: 0.1368 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 26/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.1529 - accuracy: 0.9613 - val_loss: 0.1322 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 27/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.1479 - accuracy: 0.9613 - val_loss: 0.1279 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 28/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.1433 - accuracy: 0.9613 - val_loss: 0.1238 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 29/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.1390 - accuracy: 0.9613 - val_loss: 0.1200 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 30/500
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1350 - accuracy: 0.9613 - val_loss: 0.1165 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 31/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.1313 - accuracy: 0.9613 - val_loss: 0.1132 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 32/500
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1277 - accuracy: 0.9631 - val_loss: 0.1102 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 33/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.1243 - accuracy: 0.9649 - val_loss: 0.1073 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 34/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.1212 - accuracy: 0.9666 - val_loss: 0.1046 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 35/500
# 18/18 [==============================] - 0s 9ms/step - loss: 0.1182 - accuracy: 0.9666 - val_loss: 0.1021 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 36/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.1154 - accuracy: 0.9684 - val_loss: 0.0997 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 37/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.1127 - accuracy: 0.9701 - val_loss: 0.0974 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 38/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.1101 - accuracy: 0.9719 - val_loss: 0.0952 - val_accuracy: 0.9860 - lr: 0.0100
# Epoch 39/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.1077 - accuracy: 0.9719 - val_loss: 0.0931 - val_accuracy: 0.9860 - lr: 0.0100
# Epoch 40/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.1053 - accuracy: 0.9736 - val_loss: 0.0912 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 41/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.1031 - accuracy: 0.9736 - val_loss: 0.0893 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 42/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.1010 - accuracy: 0.9772 - val_loss: 0.0876 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 43/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0989 - accuracy: 0.9772 - val_loss: 0.0859 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 44/500
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0971 - accuracy: 0.9772 - val_loss: 0.0844 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 45/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0951 - accuracy: 0.9772 - val_loss: 0.0828 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 46/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0933 - accuracy: 0.9754 - val_loss: 0.0813 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 47/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0916 - accuracy: 0.9772 - val_loss: 0.0798 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 48/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0899 - accuracy: 0.9789 - val_loss: 0.0785 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 49/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0884 - accuracy: 0.9789 - val_loss: 0.0772 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 50/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0869 - accuracy: 0.9789 - val_loss: 0.0759 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 51/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0854 - accuracy: 0.9789 - val_loss: 0.0747 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 52/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0839 - accuracy: 0.9807 - val_loss: 0.0735 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 53/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0825 - accuracy: 0.9807 - val_loss: 0.0724 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 54/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0812 - accuracy: 0.9789 - val_loss: 0.0714 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 55/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0799 - accuracy: 0.9807 - val_loss: 0.0704 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 56/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0787 - accuracy: 0.9807 - val_loss: 0.0694 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 57/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0774 - accuracy: 0.9807 - val_loss: 0.0684 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 58/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0764 - accuracy: 0.9807 - val_loss: 0.0674 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 59/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0752 - accuracy: 0.9824 - val_loss: 0.0665 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 60/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0741 - accuracy: 0.9842 - val_loss: 0.0656 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 61/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0731 - accuracy: 0.9824 - val_loss: 0.0648 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 62/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0720 - accuracy: 0.9824 - val_loss: 0.0639 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 63/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0710 - accuracy: 0.9824 - val_loss: 0.0632 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 64/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0700 - accuracy: 0.9824 - val_loss: 0.0624 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 65/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0691 - accuracy: 0.9842 - val_loss: 0.0616 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 66/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0682 - accuracy: 0.9824 - val_loss: 0.0609 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 67/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0673 - accuracy: 0.9842 - val_loss: 0.0602 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 68/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0665 - accuracy: 0.9842 - val_loss: 0.0595 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 69/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0656 - accuracy: 0.9842 - val_loss: 0.0588 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 70/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0648 - accuracy: 0.9842 - val_loss: 0.0581 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 71/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0640 - accuracy: 0.9842 - val_loss: 0.0576 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 72/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0632 - accuracy: 0.9842 - val_loss: 0.0570 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 73/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0625 - accuracy: 0.9842 - val_loss: 0.0564 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 74/500
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0617 - accuracy: 0.9842 - val_loss: 0.0558 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 75/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0610 - accuracy: 0.9842 - val_loss: 0.0553 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 76/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0603 - accuracy: 0.9859 - val_loss: 0.0547 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 77/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0596 - accuracy: 0.9859 - val_loss: 0.0542 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 78/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0589 - accuracy: 0.9859 - val_loss: 0.0537 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 79/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0583 - accuracy: 0.9859 - val_loss: 0.0532 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 80/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0577 - accuracy: 0.9859 - val_loss: 0.0527 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 81/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0571 - accuracy: 0.9877 - val_loss: 0.0522 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 82/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0564 - accuracy: 0.9895 - val_loss: 0.0517 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 83/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0559 - accuracy: 0.9895 - val_loss: 0.0513 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 84/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0553 - accuracy: 0.9895 - val_loss: 0.0508 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 85/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0547 - accuracy: 0.9912 - val_loss: 0.0504 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 86/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0542 - accuracy: 0.9912 - val_loss: 0.0500 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 87/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0536 - accuracy: 0.9912 - val_loss: 0.0496 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 88/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0531 - accuracy: 0.9912 - val_loss: 0.0491 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 89/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0525 - accuracy: 0.9912 - val_loss: 0.0487 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 90/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0521 - accuracy: 0.9912 - val_loss: 0.0483 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 91/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0516 - accuracy: 0.9912 - val_loss: 0.0480 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 92/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0511 - accuracy: 0.9912 - val_loss: 0.0477 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 93/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0506 - accuracy: 0.9895 - val_loss: 0.0473 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 94/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0502 - accuracy: 0.9912 - val_loss: 0.0468 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 95/500
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0497 - accuracy: 0.9912 - val_loss: 0.0465 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 96/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0493 - accuracy: 0.9912 - val_loss: 0.0461 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 97/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0488 - accuracy: 0.9912 - val_loss: 0.0458 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 98/500
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0484 - accuracy: 0.9912 - val_loss: 0.0454 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 99/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0480 - accuracy: 0.9912 - val_loss: 0.0451 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 100/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0476 - accuracy: 0.9895 - val_loss: 0.0448 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 101/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0472 - accuracy: 0.9912 - val_loss: 0.0445 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 102/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0468 - accuracy: 0.9912 - val_loss: 0.0442 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 103/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0464 - accuracy: 0.9895 - val_loss: 0.0438 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 104/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0461 - accuracy: 0.9912 - val_loss: 0.0436 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 105/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0457 - accuracy: 0.9895 - val_loss: 0.0433 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 106/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0453 - accuracy: 0.9895 - val_loss: 0.0430 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 107/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0450 - accuracy: 0.9895 - val_loss: 0.0428 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 108/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0447 - accuracy: 0.9912 - val_loss: 0.0425 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 109/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0444 - accuracy: 0.9895 - val_loss: 0.0423 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 110/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0440 - accuracy: 0.9895 - val_loss: 0.0421 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 111/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0437 - accuracy: 0.9895 - val_loss: 0.0418 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 112/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0433 - accuracy: 0.9895 - val_loss: 0.0416 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 113/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0430 - accuracy: 0.9895 - val_loss: 0.0413 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 114/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0427 - accuracy: 0.9895 - val_loss: 0.0410 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 115/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0424 - accuracy: 0.9895 - val_loss: 0.0408 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 116/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0421 - accuracy: 0.9895 - val_loss: 0.0406 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 117/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0418 - accuracy: 0.9895 - val_loss: 0.0403 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 118/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0415 - accuracy: 0.9895 - val_loss: 0.0400 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 119/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0413 - accuracy: 0.9895 - val_loss: 0.0398 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 120/500
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0409 - accuracy: 0.9895 - val_loss: 0.0396 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 121/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0406 - accuracy: 0.9895 - val_loss: 0.0394 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 122/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0404 - accuracy: 0.9895 - val_loss: 0.0392 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 123/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0401 - accuracy: 0.9895 - val_loss: 0.0389 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 124/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0398 - accuracy: 0.9895 - val_loss: 0.0388 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 125/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0395 - accuracy: 0.9895 - val_loss: 0.0386 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 126/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0393 - accuracy: 0.9895 - val_loss: 0.0383 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 127/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0390 - accuracy: 0.9895 - val_loss: 0.0382 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 128/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0388 - accuracy: 0.9895 - val_loss: 0.0380 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 129/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0386 - accuracy: 0.9895 - val_loss: 0.0378 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 130/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0383 - accuracy: 0.9895 - val_loss: 0.0376 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 131/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0381 - accuracy: 0.9895 - val_loss: 0.0374 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 132/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0378 - accuracy: 0.9895 - val_loss: 0.0372 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 133/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0376 - accuracy: 0.9895 - val_loss: 0.0372 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 134/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0373 - accuracy: 0.9895 - val_loss: 0.0370 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 135/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0371 - accuracy: 0.9895 - val_loss: 0.0369 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 136/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0369 - accuracy: 0.9912 - val_loss: 0.0367 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 137/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0367 - accuracy: 0.9895 - val_loss: 0.0365 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 138/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0365 - accuracy: 0.9895 - val_loss: 0.0363 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 139/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0363 - accuracy: 0.9912 - val_loss: 0.0361 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 140/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0361 - accuracy: 0.9912 - val_loss: 0.0360 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 141/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0358 - accuracy: 0.9895 - val_loss: 0.0359 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 142/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0356 - accuracy: 0.9912 - val_loss: 0.0357 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 143/500
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0354 - accuracy: 0.9912 - val_loss: 0.0356 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 144/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0352 - accuracy: 0.9912 - val_loss: 0.0354 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 145/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0350 - accuracy: 0.9912 - val_loss: 0.0353 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 146/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0348 - accuracy: 0.9912 - val_loss: 0.0352 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 147/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0346 - accuracy: 0.9930 - val_loss: 0.0351 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 148/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0344 - accuracy: 0.9930 - val_loss: 0.0349 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 149/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0342 - accuracy: 0.9930 - val_loss: 0.0348 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 150/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0340 - accuracy: 0.9930 - val_loss: 0.0347 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 151/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0338 - accuracy: 0.9930 - val_loss: 0.0346 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 152/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0337 - accuracy: 0.9947 - val_loss: 0.0345 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 153/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0335 - accuracy: 0.9947 - val_loss: 0.0343 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 154/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0333 - accuracy: 0.9947 - val_loss: 0.0342 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 155/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0331 - accuracy: 0.9947 - val_loss: 0.0341 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 156/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0330 - accuracy: 0.9947 - val_loss: 0.0340 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 157/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0328 - accuracy: 0.9947 - val_loss: 0.0339 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 158/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0326 - accuracy: 0.9947 - val_loss: 0.0337 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 159/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0325 - accuracy: 0.9947 - val_loss: 0.0336 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 160/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0323 - accuracy: 0.9947 - val_loss: 0.0335 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 161/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0321 - accuracy: 0.9947 - val_loss: 0.0334 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 162/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0320 - accuracy: 0.9947 - val_loss: 0.0334 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 163/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0318 - accuracy: 0.9947 - val_loss: 0.0332 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 164/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0317 - accuracy: 0.9947 - val_loss: 0.0332 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 165/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0315 - accuracy: 0.9947 - val_loss: 0.0331 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 166/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0314 - accuracy: 0.9947 - val_loss: 0.0330 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 167/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0312 - accuracy: 0.9947 - val_loss: 0.0329 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 168/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0310 - accuracy: 0.9947 - val_loss: 0.0328 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 169/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0309 - accuracy: 0.9947 - val_loss: 0.0326 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 170/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0307 - accuracy: 0.9947 - val_loss: 0.0325 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 171/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0306 - accuracy: 0.9947 - val_loss: 0.0324 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 172/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0305 - accuracy: 0.9947 - val_loss: 0.0323 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 173/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0303 - accuracy: 0.9947 - val_loss: 0.0322 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 174/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0302 - accuracy: 0.9947 - val_loss: 0.0321 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 175/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0300 - accuracy: 0.9947 - val_loss: 0.0320 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 176/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0299 - accuracy: 0.9947 - val_loss: 0.0320 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 177/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0299 - accuracy: 0.9947 - val_loss: 0.0319 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 178/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0297 - accuracy: 0.9947 - val_loss: 0.0319 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 179/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0295 - accuracy: 0.9947 - val_loss: 0.0318 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 180/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0294 - accuracy: 0.9947 - val_loss: 0.0317 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 181/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0292 - accuracy: 0.9947 - val_loss: 0.0316 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 182/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0292 - accuracy: 0.9947 - val_loss: 0.0315 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 183/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0290 - accuracy: 0.9947 - val_loss: 0.0314 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 184/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0290 - accuracy: 0.9947 - val_loss: 0.0313 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 185/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0288 - accuracy: 0.9947 - val_loss: 0.0312 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 186/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0287 - accuracy: 0.9947 - val_loss: 0.0312 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 187/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0285 - accuracy: 0.9947 - val_loss: 0.0311 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 188/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0284 - accuracy: 0.9947 - val_loss: 0.0310 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 189/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0283 - accuracy: 0.9947 - val_loss: 0.0310 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 190/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0282 - accuracy: 0.9947 - val_loss: 0.0309 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 191/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0281 - accuracy: 0.9947 - val_loss: 0.0308 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 192/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0280 - accuracy: 0.9947 - val_loss: 0.0307 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 193/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0278 - accuracy: 0.9947 - val_loss: 0.0306 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 194/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0277 - accuracy: 0.9947 - val_loss: 0.0305 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 195/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0276 - accuracy: 0.9947 - val_loss: 0.0305 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 196/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0275 - accuracy: 0.9947 - val_loss: 0.0304 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 197/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0274 - accuracy: 0.9947 - val_loss: 0.0303 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 198/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0273 - accuracy: 0.9947 - val_loss: 0.0303 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 199/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0271 - accuracy: 0.9947 - val_loss: 0.0302 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 200/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0271 - accuracy: 0.9947 - val_loss: 0.0301 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 201/500
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0269 - accuracy: 0.9947 - val_loss: 0.0300 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 202/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0269 - accuracy: 0.9947 - val_loss: 0.0299 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 203/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0268 - accuracy: 0.9947 - val_loss: 0.0298 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 204/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0267 - accuracy: 0.9947 - val_loss: 0.0297 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 205/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0265 - accuracy: 0.9947 - val_loss: 0.0297 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 206/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0264 - accuracy: 0.9947 - val_loss: 0.0296 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 207/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0263 - accuracy: 0.9947 - val_loss: 0.0296 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 208/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0262 - accuracy: 0.9947 - val_loss: 0.0295 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 209/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0261 - accuracy: 0.9947 - val_loss: 0.0294 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 210/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0261 - accuracy: 0.9947 - val_loss: 0.0293 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 211/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0260 - accuracy: 0.9947 - val_loss: 0.0293 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 212/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0259 - accuracy: 0.9947 - val_loss: 0.0292 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 213/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0258 - accuracy: 0.9947 - val_loss: 0.0292 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 214/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0257 - accuracy: 0.9947 - val_loss: 0.0292 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 215/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0256 - accuracy: 0.9947 - val_loss: 0.0291 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 216/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0255 - accuracy: 0.9947 - val_loss: 0.0291 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 217/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0254 - accuracy: 0.9947 - val_loss: 0.0290 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 218/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0253 - accuracy: 0.9947 - val_loss: 0.0290 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 219/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0252 - accuracy: 0.9947 - val_loss: 0.0289 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 220/500
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0251 - accuracy: 0.9947 - val_loss: 0.0288 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 221/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0251 - accuracy: 0.9947 - val_loss: 0.0287 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 222/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0250 - accuracy: 0.9947 - val_loss: 0.0287 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 223/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0248 - accuracy: 0.9947 - val_loss: 0.0286 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 224/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0247 - accuracy: 0.9947 - val_loss: 0.0286 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 225/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0247 - accuracy: 0.9947 - val_loss: 0.0285 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 226/500
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0246 - accuracy: 0.9947 - val_loss: 0.0284 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 227/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0245 - accuracy: 0.9947 - val_loss: 0.0283 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 228/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0244 - accuracy: 0.9947 - val_loss: 0.0283 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 229/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0243 - accuracy: 0.9947 - val_loss: 0.0282 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 230/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0243 - accuracy: 0.9947 - val_loss: 0.0281 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 231/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0242 - accuracy: 0.9947 - val_loss: 0.0281 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 232/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0241 - accuracy: 0.9947 - val_loss: 0.0280 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 233/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0240 - accuracy: 0.9947 - val_loss: 0.0280 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 234/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0240 - accuracy: 0.9947 - val_loss: 0.0279 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 235/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0239 - accuracy: 0.9947 - val_loss: 0.0279 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 236/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0238 - accuracy: 0.9947 - val_loss: 0.0280 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 237/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0237 - accuracy: 0.9947 - val_loss: 0.0279 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 238/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0236 - accuracy: 0.9947 - val_loss: 0.0279 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 239/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0236 - accuracy: 0.9947 - val_loss: 0.0278 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 240/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0235 - accuracy: 0.9947 - val_loss: 0.0278 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 241/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0234 - accuracy: 0.9947 - val_loss: 0.0278 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 242/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0234 - accuracy: 0.9947 - val_loss: 0.0277 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 243/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0233 - accuracy: 0.9947 - val_loss: 0.0276 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 244/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0232 - accuracy: 0.9947 - val_loss: 0.0275 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 245/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0232 - accuracy: 0.9947 - val_loss: 0.0275 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 246/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0231 - accuracy: 0.9947 - val_loss: 0.0275 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 247/500
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0230 - accuracy: 0.9947 - val_loss: 0.0275 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 248/500
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0229 - accuracy: 0.9947 - val_loss: 0.0275 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 249/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0229 - accuracy: 0.9947 - val_loss: 0.0274 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 250/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0228 - accuracy: 0.9947 - val_loss: 0.0274 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 251/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0227 - accuracy: 0.9947 - val_loss: 0.0273 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 252/500
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0226 - accuracy: 0.9947 - val_loss: 0.0272 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 253/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0225 - accuracy: 0.9947 - val_loss: 0.0272 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 254/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0225 - accuracy: 0.9947 - val_loss: 0.0271 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 255/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0224 - accuracy: 0.9947 - val_loss: 0.0270 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 256/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0223 - accuracy: 0.9947 - val_loss: 0.0270 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 257/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0223 - accuracy: 0.9947 - val_loss: 0.0270 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 258/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0223 - accuracy: 0.9947 - val_loss: 0.0269 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 259/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0222 - accuracy: 0.9947 - val_loss: 0.0269 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 260/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0221 - accuracy: 0.9947 - val_loss: 0.0268 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 261/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0220 - accuracy: 0.9947 - val_loss: 0.0268 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 262/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0220 - accuracy: 0.9947 - val_loss: 0.0268 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 263/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0219 - accuracy: 0.9947 - val_loss: 0.0267 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 264/500
# 18/18 [==============================] - 0s 10ms/step - loss: 0.0219 - accuracy: 0.9947 - val_loss: 0.0266 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 265/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0218 - accuracy: 0.9947 - val_loss: 0.0266 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 266/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0217 - accuracy: 0.9947 - val_loss: 0.0265 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 267/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0216 - accuracy: 0.9947 - val_loss: 0.0266 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 268/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0216 - accuracy: 0.9947 - val_loss: 0.0265 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 269/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0215 - accuracy: 0.9947 - val_loss: 0.0264 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 270/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0215 - accuracy: 0.9947 - val_loss: 0.0264 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 271/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0215 - accuracy: 0.9947 - val_loss: 0.0263 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 272/500
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0213 - accuracy: 0.9947 - val_loss: 0.0262 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 273/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0213 - accuracy: 0.9947 - val_loss: 0.0261 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 274/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0212 - accuracy: 0.9947 - val_loss: 0.0261 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 275/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0212 - accuracy: 0.9947 - val_loss: 0.0261 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 276/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0211 - accuracy: 0.9947 - val_loss: 0.0260 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 277/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0211 - accuracy: 0.9947 - val_loss: 0.0260 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 278/500
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0210 - accuracy: 0.9947 - val_loss: 0.0260 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 279/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0209 - accuracy: 0.9947 - val_loss: 0.0260 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 280/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0208 - accuracy: 0.9947 - val_loss: 0.0259 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 281/500
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0208 - accuracy: 0.9947 - val_loss: 0.0259 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 282/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0208 - accuracy: 0.9947 - val_loss: 0.0257 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 283/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0207 - accuracy: 0.9947 - val_loss: 0.0257 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 284/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0206 - accuracy: 0.9947 - val_loss: 0.0257 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 285/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0206 - accuracy: 0.9947 - val_loss: 0.0256 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 286/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0206 - accuracy: 0.9947 - val_loss: 0.0256 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 287/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0205 - accuracy: 0.9947 - val_loss: 0.0255 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 288/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0205 - accuracy: 0.9947 - val_loss: 0.0254 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 289/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0204 - accuracy: 0.9947 - val_loss: 0.0254 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 290/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0203 - accuracy: 0.9947 - val_loss: 0.0253 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 291/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0203 - accuracy: 0.9947 - val_loss: 0.0253 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 292/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0202 - accuracy: 0.9947 - val_loss: 0.0252 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 293/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0202 - accuracy: 0.9947 - val_loss: 0.0252 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 294/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0201 - accuracy: 0.9947 - val_loss: 0.0252 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 295/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0201 - accuracy: 0.9947 - val_loss: 0.0252 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 296/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0200 - accuracy: 0.9947 - val_loss: 0.0251 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 297/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0200 - accuracy: 0.9947 - val_loss: 0.0251 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 298/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0199 - accuracy: 0.9947 - val_loss: 0.0251 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 299/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0199 - accuracy: 0.9947 - val_loss: 0.0250 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 300/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0198 - accuracy: 0.9947 - val_loss: 0.0250 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 301/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0198 - accuracy: 0.9947 - val_loss: 0.0249 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 302/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0197 - accuracy: 0.9947 - val_loss: 0.0249 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 303/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0197 - accuracy: 0.9947 - val_loss: 0.0249 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 304/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0196 - accuracy: 0.9947 - val_loss: 0.0249 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 305/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0195 - accuracy: 0.9947 - val_loss: 0.0249 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 306/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0195 - accuracy: 0.9947 - val_loss: 0.0248 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 307/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0194 - accuracy: 0.9947 - val_loss: 0.0248 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 308/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0194 - accuracy: 0.9947 - val_loss: 0.0248 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 309/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0194 - accuracy: 0.9947 - val_loss: 0.0247 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 310/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0193 - accuracy: 0.9947 - val_loss: 0.0247 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 311/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0192 - accuracy: 0.9947 - val_loss: 0.0246 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 312/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0193 - accuracy: 0.9947 - val_loss: 0.0246 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 313/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0192 - accuracy: 0.9947 - val_loss: 0.0245 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 314/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0191 - accuracy: 0.9947 - val_loss: 0.0246 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 315/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0190 - accuracy: 0.9947 - val_loss: 0.0246 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 316/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0190 - accuracy: 0.9947 - val_loss: 0.0244 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 317/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0190 - accuracy: 0.9947 - val_loss: 0.0244 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 318/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0190 - accuracy: 0.9947 - val_loss: 0.0243 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 319/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0189 - accuracy: 0.9947 - val_loss: 0.0242 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 320/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0189 - accuracy: 0.9947 - val_loss: 0.0242 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 321/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0188 - accuracy: 0.9947 - val_loss: 0.0242 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 322/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0188 - accuracy: 0.9947 - val_loss: 0.0242 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 323/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0187 - accuracy: 0.9947 - val_loss: 0.0242 - val_accuracy: 0.9930 - lr: 0.0100
# Epoch 324/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0186 - accuracy: 0.9947 - val_loss: 0.0242 - val_accuracy: 0.9930 - lr: 1.0000e-03
# Epoch 325/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0185 - accuracy: 0.9947 - val_loss: 0.0242 - val_accuracy: 0.9930 - lr: 1.0000e-03
# Epoch 326/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0185 - accuracy: 0.9947 - val_loss: 0.0242 - val_accuracy: 0.9930 - lr: 1.0000e-03

# %%
from keras.models import load_model  

model=load_model('school_best.h5')  

model.evaluate(X_test_scaled, y_test, verbose=0)
# Out:
# [0.016949867829680443, 0.9943820238113403]

# %%
loss, acc_tr = model.evaluate(X_train_scaled, y_train,  verbose=0)

loss, acc_te = model.evaluate(X_test_scaled, y_test,  verbose=0)

print(acc_tr)

print(acc_te)

result_tr.append(acc_tr)

result_te.append(acc_te)
# Out:
# 0.9943820238113403
# 0.9943820238113403

# %%
#알고리즘별 예측도 그래프

methods=["LOGIT","Tree","RF","KNN","ANN","SVM","DNN"]

result_tr_arr=np.array(result_tr) #검증용 데이터셋의 정확도

max_rate_tr=np.max(result_tr_arr) #가장 좋은 정확도

idx_tr=np.argmax(result_tr_arr) #가장 성능이 좋은 인덱스

result_te_arr=np.array(result_te) #검증용 데이터셋의 정확도

max_rate_te=np.max(result_te_arr) #가장 좋은 정확도

idx_te=np.argmax(result_te_arr) #가장 성능이 좋은 인덱스

print(methods)

print(result_tr)

print(result_te)

print("최적의 모형(학습용):",methods[idx_tr])

print("최고 정확도(학습용):",max_rate_tr)        

print("최적의 모형(검증용):",methods[idx_te])

print("최고 정확도(검증용):",max_rate_te)        

        

plt.rcParams["font.size"]=15

plt.plot(methods, result_tr_arr, label="학습용 정확도")

plt.plot(methods, result_te_arr, label="검증용 정확도")

plt.xlabel("분석방법")

plt.ylabel("정확도")

plt.legend()
# Out:
# ['LOGIT', 'Tree', 'RF', 'KNN', 'ANN', 'SVM', 'DNN']
# [0.9887640449438202, 0.9789325842696629, 1.0, 0.9803370786516854, 0.9943820224719101, 0.9929775280898876, 0.9943820238113403]
# [0.9943820224719101, 0.9775280898876404, 0.9943820224719101, 0.9719101123595506, 0.9943820224719101, 1.0, 0.9943820238113403]
# 최적의 모형(학습용): RF
# 최고 정확도(학습용): 1.0
# 최적의 모형(검증용): SVM
# 최고 정확도(검증용): 1.0
