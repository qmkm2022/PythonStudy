# %% [markdown]
# # 서울시 구별 주유소 데이터 분석 및 시각화

# %%
import numpy as np
import pandas as pd
import requests
from urllib.parse import quote
import folium, json

# %%
df = pd.read_csv(r'C:/workspace/서울_주유소(230418).csv')

# %%
# 구별 집계 분석
gu_mm = df.groupby('구')['가격'].agg(['mean', 'min', 'max'])
gu_mm
# Out:
#              mean   min   max
# 구
# 강남구   1942.294118  1623  2578
# 강동구   1735.000000  1669  1978
# 강북구   1649.916667  1629  1707
# 강서구   1696.818182  1628  1995
# 관악구   1744.714286  1685  1852
# 광진구   1684.538462  1654  1748
# 구로구   1737.200000  1645  2198
# 금천구   1699.090909  1665  1769
# 노원구   1699.428571  1629  1795
# 도봉구   1673.687500  1639  1767
# 동대문구  1687.055556  1615  1790
# 동작구   1738.333333  1639  1835
# 마포구   1699.909091  1637  1764
# 서대문구  1669.428571  1619  1728
# 서초구   1737.033333  1594  1989
# 성동구   1797.062500  1625  2148
# 성북구   1693.782609  1625  1892
# 송파구   1684.827586  1633  1848
# 양천구   1676.291667  1595  1779
# 영등포구  1731.851852  1625  2199
# 용산구   2169.500000  1948  2749
# 은평구   1639.000000  1604  1748
# 종로구   1951.000000  1689  2240
# 중구    2053.400000  1649  2753
# 중랑구   1661.153846  1635  1719

# %%
# 해당구에서 최대값 최소값만 구하기
# 예 강남구
_, mi, ma = gu_mm.loc['강남구']
mi, ma = int(mi), int(ma)
mi, ma
# Out:
# (1623, 2578)

# %%
# 컬럼을 하나 추가하여 최대값인지 최속값인지 결정해서 넣을 예정
df['mm'] = np.zeros(df.shape[0], int)
df.head()
# Out:
#             상호                       주소    가격 셀프      상표    구  mm
# 0  (주)보성 세곡주유소    서울 강남구  헌릉로 731 (세곡동)  1623  Y   SK에너지  강남구   0
# 1      자곡셀프주유소    서울 강남구 밤고개로 120 (자곡동)  1669  Y   SK에너지  강남구   0
# 2       삼성동주유소    서울 강남구 테헤란로 619 (삼성동)  1684  Y  현대오일뱅크  강남구   0
# 3        방죽주유소    서울 강남구 밤고개로 215 (율현동)  1687  Y   GS칼텍스  강남구   0
# 4     오일프러스 셀프  서울 강남구 남부순환로 2651 (도곡동)  1704  Y   SK에너지  강남구   0

# %%
# mm 컬럼에 최소값이 같으면 1을 넣고 최대값과 같으면 2를 넣을것
for gu in gu_mm.index:
    _, mi, ma = gu_mm.loc[gu]
    mi, ma = int(mi) , int(ma)
    for i in df.index:
        if df.가격[i] == mi and df.구[i] == gu:
            df.mm[i] = 1
        if df.가격[i] == ma and df.구[i] == gu:
            df.mm[i] = 2
# Out:
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_10392\1260248008.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.mm[i] = 1
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_10392\1260248008.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.mm[i] = 2

# %%
# mm 컬럼에 데이터가 있는 행만 추출
df1 = df[df.mm !=0]
df1.head()
# Out:
#                       상호                            주소    가격 셀프      상표    구  \
# 0            (주)보성 세곡주유소         서울 강남구  헌릉로 731 (세곡동)  1623  Y   SK에너지  강남구
# 33        (주)만정에너지 삼보주유소         서울 강남구 봉은사로 433 (삼성동)  2578  N   GS칼텍스  강남구
# 34  재건에너지 재정제2주유소 고속셀프지점  서울특별시 강동구  천호대로 1246 (둔촌제2동)  1669  Y  현대오일뱅크  강동구
# 46                 광성주유소         서울 강동구 올림픽로 673 (천호동)  1978  N   S-OIL  강동구
# 47        SK에너지(주) 매일주유소          서울 강북구 삼양로 217 (미아동)  1629  Y   SK에너지  강북구
#
#     mm
# 0    1
# 33   2
# 34   1
# 46   2
# 47   1

# %%
df1.shape
# Out:
# (70, 7)

# %% [markdown]
# # 지도 시각화

# %%
# KAKAO API로 위,경도값을 추출
with open('C:/workspace/data1/kakaoAPI.txt') as file:
    kakao_key = file.read()

# %%
lat_list = [] 
lng_list = []
for i in df1.index:
    search_url = 'https://dapi.kakao.com/v2/local/search/address.json'
    url = f'{search_url}?query={quote(df1.주소[i])}'
    result = requests.get(url, headers={"Authorization" : f'KakaoAK {kakao_key}'}).json()
    try:
        lng_list.append(float(result['documents'][0]['x']))
        lat_list.append(float(result['documents'][0]['y']))
    except:
        print(df1.상호[i])

# %%
df1['위도'] = lat_list
df1['경도'] = lng_list
df1.head()
# Out:
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_10392\2420660999.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['위도'] = lat_list
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_10392\2420660999.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['경도'] = lng_list
#                       상호                            주소    가격 셀프      상표    구  \
# 0            (주)보성 세곡주유소         서울 강남구  헌릉로 731 (세곡동)  1623  Y   SK에너지  강남구
# 33        (주)만정에너지 삼보주유소         서울 강남구 봉은사로 433 (삼성동)  2578  N   GS칼텍스  강남구
# 34  재건에너지 재정제2주유소 고속셀프지점  서울특별시 강동구  천호대로 1246 (둔촌제2동)  1669  Y  현대오일뱅크  강동구
# 46                 광성주유소         서울 강동구 올림픽로 673 (천호동)  1978  N   S-OIL  강동구
# 47        SK에너지(주) 매일주유소          서울 강북구 삼양로 217 (미아동)  1629  Y   SK에너지  강북구
#
#     mm         위도          경도
# 0    1  37.467272  127.118743
# 33   2  37.511551  127.047115
# 34   1  37.536417  127.149372
# 46   2  37.541577  127.124242
# 47   1  37.622765  127.019086

# %%
filename = './data1/skorea_municipalities_geo_simple.json'
geo_str = json.load(open(filename, encoding='utf-8'))

# %%
map = folium.Map(location=[df1.위도.mean(), df1.경도.mean()], zoom_start=12)
for i in df1.index:
    folium.Marker(
        location=[df1.위도[i], df1.경도[i]],
        popup=folium.Popup(df.주소[i], max_width=200),
        tooltip=f'{df1.상호[i]}<br>휘발유:{df1.가격[i]:,d}원',
        icon=folium.Icon(color='green' if df.mm[i] == 1 else 'red',
                        icon = 'glyphicon glyphicon-thumbs-up' 
                         if df.mm[i] == 1 else 'glyphicon glyphicon-thumbs-down')
    ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1fadd89398aa664e0b338537775c61ce {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1fadd89398aa664e0b338537775c61ce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1fadd89398aa664e0b338537775c61ce = L.map(
#                 &quot;map_1fadd89398aa664e0b338537775c61ce&quot;,
#                 {
#                     center: [37.55411328345298, 126.98297020858621],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0a119a185ec7beaf3957030ffd8b9025 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1fadd89398aa664e0b338537775c61ce);
#
#
#             var marker_f91d5fcb212888cacab4f04bff273852 = L.marker(
#                 [37.4672717183911, 127.118742598267],
#                 {}
#             ).addTo(map_1fadd89398aa664e0b338537775c61ce);
#
#
#             var icon_3a5a9e33c5ed30a3aa2e1a31aaccaa7f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon glyphicon-thumbs-up&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f91d5fcb212888cacab4f04bff273852.setIcon(icon_3a5a9e33c5ed30a3aa2e1a31aaccaa7f);
#
#
#         var popup_c6f3e830ba6ebedf6bdf5537f80dbfc2 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_0ce532d808086bfc0c0fe3c9bf96af78 = $(`&lt;div id=&quot;html_0ce532d808086bfc0c0fe3c9bf96af78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울 강남구  헌릉로 731 (세곡동)&lt;/div&gt;`)[0];
#                 popup_c6f3e830ba6ebedf6bdf5537f80dbfc2.setContent(html_0ce532d808086bfc0c0fe3c9bf96af78);
#
#
#
#         marker_f91d5fcb212888cacab4f04bff273852.bindPopup(popup_c6f3e830ba6ebedf6bdf5537f80dbfc2)
#         ;
#
#
#
#
#             marker_f91d5fcb212888cacab4f04bff273852.bindTooltip(
#                 `&lt;div&gt;
#                      (주)보성 세곡주유소&lt;br&gt;휘발유:1,623원
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4156a70285ad1344cb56b982bbb5df1f = L.marker(
#                 [37.5115512804432, 127.047114626083],
#                 {}
#             ).addTo(map_1fadd89398aa664e0b338537775c61ce);
#
#
#             var icon_1cd5e4dbff8f1b558fcee5a59ee5b59b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon glyphicon-thumbs-down&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4156a70285ad1344cb56b982bbb5df1f.setIcon(icon_1cd5e4dbff8f1b558fcee5a59ee5b59b);
#
#
#         var popup_03a02972a8dadc3b02215a5a0f9a5462 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_30a40285a5b44a78dd7f5408560c748e = $(`&lt;div id=&quot;html_30a40285a5b44a78dd7f5408560c748e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울 강남구 봉은사로 433 (삼성동)&lt;/div&gt;`)[0];
#                 popup_03a02972a8dadc3b02215a5a0f9a5462.setContent(html_30a40285a5b44a78dd7f5408560c748e);
#
#
#
#         marker_4156a70285ad1344cb56b982bbb5df1f.bindPopup(popup_03a02972a8dadc3b02215a5a0f9a5462)
#         ;
#
#
#
#
#             marker_4156a70285ad1344cb56b982bbb5df1f.bindTooltip(
#                 `&lt;div&gt;
#                      (주)만정에너지 삼보주유소&lt;br&gt;휘발유:2,578원
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6077fb4f4225df928282b64fe5e13336 = L.marker(
#                 [37.5364168582452, 127.149372429092],
#                 {}
#             ).addTo(map_1fadd89398aa664e0b338537775c61ce);
#
#
#             var icon_991b6604f96c377b574a3edcb7871f7e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;glyphicon glyphicon-thumbs-up&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6077fb4f4225df928282b64fe5e13336.setIcon(icon_991b6604f96c377b574a3edcb7871f7e);
#
#
#         var popup_38ebace97fbbe4dc0f7850550c501319 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_2e770a33023f2c40311b1890eb918677 = $(`&lt;div id=&quot;html_2e770a33023f2c40311b1890eb918677&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 강동구  천호대로 1246 (둔촌제2동)&lt;/div&gt;`)[0];

# %%
# 단계구분도 나중에...과제 평균으로 단계 구분도를 그리고 주유소 .
# stamen Toner
